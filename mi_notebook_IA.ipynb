# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMartinez2335/mi-proyecto-de-IA/blob/main/mi_notebook_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mi primer código de IA
import numpy as np
print("Hola desde Colab!")

# %%
datos = [1, 2, 3, 4, 5]
media = np.mean(datos)
print(f"La media es: {media}")
